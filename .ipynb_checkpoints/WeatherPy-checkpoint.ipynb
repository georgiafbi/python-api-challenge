# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
# Import API key
from api_keys import weather_api_key
from datetime import datetime

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
city=[]
lat=[]
lng=[]
humidity=[]
clouds=[]
windspeed=[]
country=[]
date=[]
max_temp=[]
weather_dict ={"City": city,"Latitude":lat,"Longitude":lng,"Max Temperature (Celsius)": max_temp,"Humidity (%)":humidity,"Cloudiness (%)":clouds,"Wind Speed (MPH)":windspeed,"Country": country,"Date":date}
j=1
print("Beginning Data Retrieval\n-----------------------------")
#Build query url
for i in range(len(cities)):
    url=f'https://api.openweathermap.org/data/2.5/weather?q={cities[i]}&appid={weather_api_key}'
    #get weather data
    weather_response = requests.get(url)
    weather_json=weather_response.json()
    try:
        city.append(weather_json['name'])
        lat.append(weather_json['coord']['lat'])
        lng.append(weather_json['coord']['lon'])
        max_temp.append(round(weather_json['main']['temp_max']-273.15,2))
        humidity.append(weather_json['main']['humidity'])
        clouds.append(weather_json['clouds']['all'])
        windspeed.append(weather_json['wind']['speed'])
        country.append(weather_json['sys']['country'])
        date.append(time.strftime('%D %H:%M', time.localtime(int(weather_json['dt']))))
        if i == j*50:
            j+=1
        print(f"Processing Record {i+1} of set {j} | {city[-1]}")
    except KeyError:
        if i == j*50:
            j+=1
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of set 1 | Hithadhoo
# City not found. Skipping...
# Processing Record 3 of set 1 | Rikitea
# Processing Record 4 of set 1 | Mataura
# Processing Record 5 of set 1 | Ilulissat
# Processing Record 6 of set 1 | Dikson
# Processing Record 7 of set 1 | Pemangkat
# Processing Record 8 of set 1 | Tovuz
# Processing Record 9 of set 1 | Hermanus
# Processing Record 10 of set 1 | Cape Town
# Processing Record 11 of set 1 | Ushuaia
# Processing Record 12 of set 1 | Punta Arenas
# Processing Record 13 of set 1 | Sinazongwe
# Processing Record 14 of set 1 | Aklavik
# Processing Record 15 of set 1 | Totness
# Processing Record 16 of set 1 | Saint-Philippe
# Processing Record 17 of set 1 | Tiksi
# Processing Record 18 of set 1 | Karratha
# Processing Record 19 of set 1 | Oxbow
# Processing Record 20 of set 1 | Arraial do Cabo
# Processing Record 21 of set 1 | Lata
# Processing Record 22 of set 1 | Oxford
# Processing Record 23 of set 1 | Acarí
# Processing Record 24 of set 1 | Hastings
# Processing Record 25 of set 1 | Albany
# City not found. Skipping...
# Processing Record 27 of set 1 | Voyvozh
# Processing Record 28 of set 1 | Bethel
# Processing Record 29 of set 1 | Uíge
# Processing Record 30 of set 1 | Aksarka
# City not found. Skipping...
# Processing Record 32 of set 1 | Kavaratti
# Processing Record 33 of set 1 | Brandon
# Processing Record 34 of set 1 | Nikolskoye
# Processing Record 35 of set 1 | Hualmay
# Processing Record 36 of set 1 | Jamestown
# Processing Record 37 of set 1 | Hilo
# Processing Record 38 of set 1 | Kaitangata
# Processing Record 39 of set 1 | Severo-Kuril'sk
# Processing Record 40 of set 1 | Kahului
# Processing Record 41 of set 1 | George Town
# Processing Record 42 of set 1 | Lüderitz
# Processing Record 43 of set 1 | Geraldton
# Processing Record 44 of set 1 | East London
# City not found. Skipping...
# Processing Record 46 of set 1 | Atuona
# Processing Record 47 of set 1 | Yellowknife
# Processing Record 48 of set 1 | Kapaa
# Processing Record 49 of set 1 | Kumul
# City not found. Skipping...
# Processing Record 51 of set 2 | Lorengau
# Processing Record 52 of set 2 | Bakchar
# City not found. Skipping...
# Processing Record 54 of set 2 | Bouna
# Processing Record 55 of set 2 | Mandurah
# Processing Record 56 of set 2 | Kavieng
# Processing Record 57 of set 2 | Chui
# City not found. Skipping...
# Processing Record 59 of set 2 | Blagoyevo
# Processing Record 60 of set 2 | Khatanga
# Processing Record 61 of set 2 | Ribeira Grande
# Processing Record 62 of set 2 | Port Alfred
# Processing Record 63 of set 2 | Cidreira
# Processing Record 64 of set 2 | Aquidauana
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 67 of set 2 | Vao
# Processing Record 68 of set 2 | Cayenne
# Processing Record 69 of set 2 | Barrow
# Processing Record 70 of set 2 | Rocha
# Processing Record 71 of set 2 | Dunedin
# Processing Record 72 of set 2 | Taoudenni
# Processing Record 73 of set 2 | Airai
# Processing Record 74 of set 2 | Molina
# Processing Record 75 of set 2 | Haines Junction
# Processing Record 76 of set 2 | Iqaluit
# City not found. Skipping...
# Processing Record 78 of set 2 | Isangel
# Processing Record 79 of set 2 | Sayyan
# Processing Record 80 of set 2 | Oktyabr'skoye
# Processing Record 81 of set 2 | Cabo San Lucas
# Processing Record 82 of set 2 | Busselton
# Processing Record 83 of set 2 | Zorritos
# Processing Record 84 of set 2 | Bluff
# Processing Record 85 of set 2 | Lyuban'
# City not found. Skipping...
# Processing Record 87 of set 2 | Magistral'nyy
# Processing Record 88 of set 2 | Moose Factory
# Processing Record 89 of set 2 | Arman'
# Processing Record 90 of set 2 | Bow Island
# Processing Record 91 of set 2 | Leningradskiy
# Processing Record 92 of set 2 | Yabēlo
# Processing Record 93 of set 2 | Ürümqi
# Processing Record 94 of set 2 | Ponta do Sol
# Processing Record 95 of set 2 | Atar
# Processing Record 96 of set 2 | Half Moon Bay
# Processing Record 97 of set 2 | Hong Kong
# Processing Record 98 of set 2 | Okhotsk
# Processing Record 99 of set 2 | Norman Wells
# Processing Record 100 of set 2 | Bredasdorp
# Processing Record 101 of set 3 | Clyde River
# Processing Record 102 of set 3 | San Vicente
# Processing Record 103 of set 3 | Varzob
# Processing Record 104 of set 3 | Hobyo
# Processing Record 105 of set 3 | Hiriyūr
# Processing Record 106 of set 3 | Goundi
# Processing Record 107 of set 3 | Nyurba
# Processing Record 108 of set 3 | Vaini
# Processing Record 109 of set 3 | Cherskiy
# Processing Record 110 of set 3 | Hambantota
# Processing Record 111 of set 3 | College
# City not found. Skipping...
# Processing Record 113 of set 3 | Imbituba
# Processing Record 114 of set 3 | Cuamba
# Processing Record 115 of set 3 | Tuatapere
# Processing Record 116 of set 3 | Provideniya
# Processing Record 117 of set 3 | Seoul
# Processing Record 118 of set 3 | Jackson
# Processing Record 119 of set 3 | Kondinskoye
# Processing Record 120 of set 3 | Tel'ma
# Processing Record 121 of set 3 | Monte Alegre de Minas
# Processing Record 122 of set 3 | Synya
# Processing Record 123 of set 3 | Araouane
# Processing Record 124 of set 3 | Helong
# Processing Record 125 of set 3 | Torbay
# City not found. Skipping...
# Processing Record 127 of set 3 | Bengkulu
# Processing Record 128 of set 3 | Zeya
# City not found. Skipping...
# Processing Record 130 of set 3 | Vanimo
# Processing Record 131 of set 3 | San Patricio
# Processing Record 132 of set 3 | Puerto Ayora
# Processing Record 133 of set 3 | Erenhot
# Processing Record 134 of set 3 | Lompoc
# Processing Record 135 of set 3 | Krasnyy Chikoy
# Processing Record 136 of set 3 | Marawi
# Processing Record 137 of set 3 | Qaqortoq
# Processing Record 138 of set 3 | Coyhaique
# Processing Record 139 of set 3 | Ahipara
# Processing Record 140 of set 3 | Beloha
# Processing Record 141 of set 3 | Upernavik
# Processing Record 142 of set 3 | Mar del Plata
# Processing Record 143 of set 3 | Sitka
# Processing Record 144 of set 3 | Hobart
# Processing Record 145 of set 3 | Saint-Pierre
# Processing Record 146 of set 3 | Namatanai
# Processing Record 147 of set 3 | Hasaki
# Processing Record 148 of set 3 | Fairbanks
# Processing Record 149 of set 3 | Akureyri
# Processing Record 150 of set 3 | Katsuura
# Processing Record 151 of set 4 | Paka
# Processing Record 152 of set 4 | Tadine
# Processing Record 153 of set 4 | Lavrentiya
# Processing Record 154 of set 4 | Saint-Leu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 157 of set 4 | Kilindoni
# Processing Record 158 of set 4 | Clearlake
# City not found. Skipping...
# Processing Record 160 of set 4 | Saskylakh
# Processing Record 161 of set 4 | Alofi
# Processing Record 162 of set 4 | Nanortalik
# City not found. Skipping...
# Processing Record 164 of set 4 | Manavālakurichi
# Processing Record 165 of set 4 | Fortuna
# Processing Record 166 of set 4 | Châlons-en-Champagne
# Processing Record 167 of set 4 | Jalu
# Processing Record 168 of set 4 | Merauke
# Processing Record 169 of set 4 | Guánica
# Processing Record 170 of set 4 | Parry Sound
# Processing Record 171 of set 4 | Tiarei
# Processing Record 172 of set 4 | Nadym
# Processing Record 173 of set 4 | Big Spring
# Processing Record 174 of set 4 | Mossamedes
# Processing Record 175 of set 4 | Sibolga
# Processing Record 176 of set 4 | Longyearbyen
# Processing Record 177 of set 4 | Paramonga
# Processing Record 178 of set 4 | Urdorf
# Processing Record 179 of set 4 | Carballo
# Processing Record 180 of set 4 | Thompson
# Processing Record 181 of set 4 | Chapais
# Processing Record 182 of set 4 | Eureka
# Processing Record 183 of set 4 | Kelowna
# Processing Record 184 of set 4 | Saldanha
# Processing Record 185 of set 4 | Prien
# Processing Record 186 of set 4 | Butaritari
# City not found. Skipping...
# Processing Record 188 of set 4 | Lebu
# Processing Record 189 of set 4 | Bilma
# Processing Record 190 of set 4 | Fevik
# Processing Record 191 of set 4 | Talnakh
# Processing Record 192 of set 4 | Aasiaat
# Processing Record 193 of set 4 | Mocuba
# Processing Record 194 of set 4 | Padang
# Processing Record 195 of set 4 | Kokstad
# Processing Record 196 of set 4 | Codrington
# Processing Record 197 of set 4 | Carutapera
# Processing Record 198 of set 4 | Avarua
# Processing Record 199 of set 4 | Uyemskiy
# Processing Record 200 of set 4 | Bredy
# Processing Record 201 of set 5 | Saint Paul Harbor
# Processing Record 202 of set 5 | Pachino
# Processing Record 203 of set 5 | Samarai
# Processing Record 204 of set 5 | Xapuri
# Processing Record 205 of set 5 | Jumla
# Processing Record 206 of set 5 | Port Hedland
# Processing Record 207 of set 5 | Alice Springs
# City not found. Skipping...
# Processing Record 209 of set 5 | Ngunguru
# Processing Record 210 of set 5 | Carnarvon
# Processing Record 211 of set 5 | Qiongshan
# Processing Record 212 of set 5 | Provincia di Cagliari
# Processing Record 213 of set 5 | Bonfim
# Processing Record 214 of set 5 | Genthin
# Processing Record 215 of set 5 | San Ramon
# Processing Record 216 of set 5 | Kitimat
# Processing Record 217 of set 5 | Pevek
# Processing Record 218 of set 5 | Härnösand
# Processing Record 219 of set 5 | Guhāgar
# Processing Record 220 of set 5 | Tabory
# Processing Record 221 of set 5 | Turan
# Processing Record 222 of set 5 | Broome
# Processing Record 223 of set 5 | Rodeo
# Processing Record 224 of set 5 | Usakos
# Processing Record 225 of set 5 | Rāwah
# Processing Record 226 of set 5 | Itacaré
# Processing Record 227 of set 5 | Puerto Quijarro
# Processing Record 228 of set 5 | Touba
# Processing Record 229 of set 5 | New Norfolk
# Processing Record 230 of set 5 | Chaoyang
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 233 of set 5 | Necochea
# Processing Record 234 of set 5 | Abnūb
# Processing Record 235 of set 5 | Peno
# Processing Record 236 of set 5 | Mehamn
# Processing Record 237 of set 5 | São Félix do Xingu
# Processing Record 238 of set 5 | Samos
# City not found. Skipping...
# Processing Record 240 of set 5 | Calabozo
# Processing Record 241 of set 5 | Poum
# Processing Record 242 of set 5 | Vardø
# Processing Record 243 of set 5 | Maragogi
# Processing Record 244 of set 5 | Tuktoyaktuk
# Processing Record 245 of set 5 | Awjilah
# Processing Record 246 of set 5 | Qaanaaq
# Processing Record 247 of set 5 | Campo Formoso
# Processing Record 248 of set 5 | Broken Hill
# Processing Record 249 of set 5 | Znamenskoye
# Processing Record 250 of set 5 | Klaksvík
# Processing Record 251 of set 6 | Sangar
# Processing Record 252 of set 6 | Nioro
# Processing Record 253 of set 6 | Puerto Ayacucho
# Processing Record 254 of set 6 | Fortuna Foothills
# Processing Record 255 of set 6 | Angoche
# Processing Record 256 of set 6 | Santa Rosa
# Processing Record 257 of set 6 | Derzhavīnsk
# Processing Record 258 of set 6 | Khāsh
# Processing Record 259 of set 6 | Meulaboh
# Processing Record 260 of set 6 | Kruisfontein
# Processing Record 261 of set 6 | Pangody
# Processing Record 262 of set 6 | Bereda
# Processing Record 263 of set 6 | Bom Jesus da Lapa
# Processing Record 264 of set 6 | Umluj
# Processing Record 265 of set 6 | Hanna
# Processing Record 266 of set 6 | Matamoros
# Processing Record 267 of set 6 | Wakkanai
# Processing Record 268 of set 6 | Superior
# Processing Record 269 of set 6 | Port Moresby
# City not found. Skipping...
# Processing Record 271 of set 6 | Vuktyl
# Processing Record 272 of set 6 | Mackay
# Processing Record 273 of set 6 | Grants Pass
# Processing Record 274 of set 6 | Haapiti
# Processing Record 275 of set 6 | Minden
# Processing Record 276 of set 6 | Stephenville
# Processing Record 277 of set 6 | Tūkrah
# Processing Record 278 of set 6 | Nakusp
# Processing Record 279 of set 6 | Carupano
# Processing Record 280 of set 6 | Port Elizabeth
# Processing Record 281 of set 6 | Bermejo
# City not found. Skipping...
# Processing Record 283 of set 6 | Dingle
# Processing Record 284 of set 6 | Mahébourg
# Processing Record 285 of set 6 | Berlevåg
# Processing Record 286 of set 6 | Chenzhou
# Processing Record 287 of set 6 | Yangi Marg`ilon
# Processing Record 288 of set 6 | Batticaloa
# Processing Record 289 of set 6 | Asău
# Processing Record 290 of set 6 | Yhú
# Processing Record 291 of set 6 | Vestmannaeyjar
# City not found. Skipping...
# Processing Record 293 of set 6 | Te Anau
# Processing Record 294 of set 6 | Castro
# Processing Record 295 of set 6 | Richards Bay
# Processing Record 296 of set 6 | Thinadhoo
# Processing Record 297 of set 6 | Gizo Government Station
# Processing Record 298 of set 6 | Oussouye
# Processing Record 299 of set 6 | Fort Nelson
# Processing Record 300 of set 6 | Pemba
# Processing Record 301 of set 7 | Ancud
# Processing Record 302 of set 7 | Eastlake
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 305 of set 7 | Rome
# City not found. Skipping...
# Processing Record 307 of set 7 | Laguna
# Processing Record 308 of set 7 | Kargil
# Processing Record 309 of set 7 | Christchurch
# Processing Record 310 of set 7 | Dakar
# Processing Record 311 of set 7 | Burns Lake
# Processing Record 312 of set 7 | Nānākuli
# Processing Record 313 of set 7 | San Julián
# Processing Record 314 of set 7 | Avera
# Processing Record 315 of set 7 | Prokhorovka
# Processing Record 316 of set 7 | Mount Gambier
# Processing Record 317 of set 7 | Tasiilaq
# Processing Record 318 of set 7 | Huarmey
# Processing Record 319 of set 7 | Baharly
# Processing Record 320 of set 7 | Palana
# Processing Record 321 of set 7 | Marsh Harbour
# Processing Record 322 of set 7 | Ishigaki
# City not found. Skipping...
# Processing Record 324 of set 7 | Tahe
# Processing Record 325 of set 7 | Almaznyy
# Processing Record 326 of set 7 | Purwodadi Grobogan
# Processing Record 327 of set 7 | Deputatsky
# Processing Record 328 of set 7 | Artigas
# Processing Record 329 of set 7 | Leh
# Processing Record 330 of set 7 | Naples
# Processing Record 331 of set 7 | Altar
# Processing Record 332 of set 7 | Krasnooktyabrskiy
# Processing Record 333 of set 7 | Gayéri
# Processing Record 334 of set 7 | Nuuk
# Processing Record 335 of set 7 | Elko
# Processing Record 336 of set 7 | Abalak
# Processing Record 337 of set 7 | Buraidah
# Processing Record 338 of set 7 | Portland
# Processing Record 339 of set 7 | Chumikan
# Processing Record 340 of set 7 | La Ronge
# Processing Record 341 of set 7 | The Pas
# Processing Record 342 of set 7 | Tynset
# Processing Record 343 of set 7 | Mandan
# Processing Record 344 of set 7 | Okha
# Processing Record 345 of set 7 | Ulladulla
# City not found. Skipping...
# Processing Record 347 of set 7 | Saint-Joseph
# Processing Record 348 of set 7 | Balkhash
# Processing Record 349 of set 7 | Vostok
# Processing Record 350 of set 7 | Kashgar
# Processing Record 351 of set 8 | Ust-Nera
# Processing Record 352 of set 8 | Zanesville
# Processing Record 353 of set 8 | Virginia Beach
# Processing Record 354 of set 8 | Kutum
# Processing Record 355 of set 8 | Grand Gaube
# Processing Record 356 of set 8 | Caraballeda
# Processing Record 357 of set 8 | Warri
# Processing Record 358 of set 8 | Ostrovnoy
# Processing Record 359 of set 8 | Maniitsoq
# Processing Record 360 of set 8 | Kristiansund
# Processing Record 361 of set 8 | Aswān
# Processing Record 362 of set 8 | Islamkot
# Processing Record 363 of set 8 | Port Hardy
# Processing Record 364 of set 8 | Seddon
# Processing Record 365 of set 8 | Carberry
# Processing Record 366 of set 8 | Kodinsk
# Processing Record 367 of set 8 | Chāmpua
# Processing Record 368 of set 8 | Flinders
# City not found. Skipping...
# Processing Record 370 of set 8 | Domodossola
# Processing Record 371 of set 8 | Bambous Virieux
# Processing Record 372 of set 8 | Guerrero Negro
# Processing Record 373 of set 8 | Viedma
# Processing Record 374 of set 8 | Magadan
# Processing Record 375 of set 8 | Ponoka
# Processing Record 376 of set 8 | Manado
# Processing Record 377 of set 8 | Abhā
# Processing Record 378 of set 8 | Souillac
# Processing Record 379 of set 8 | Ponta Delgada
# Processing Record 380 of set 8 | Port-Gentil
# Processing Record 381 of set 8 | Luganville
# Processing Record 382 of set 8 | Acaraú
# Processing Record 383 of set 8 | Yulara
# Processing Record 384 of set 8 | Porto Santo
# Processing Record 385 of set 8 | Peniche
# Processing Record 386 of set 8 | Saint George
# Processing Record 387 of set 8 | Alihe
# Processing Record 388 of set 8 | Yerbogachën
# Processing Record 389 of set 8 | Constitución
# Processing Record 390 of set 8 | Koumac
# Processing Record 391 of set 8 | Vila Franca do Campo
# Processing Record 392 of set 8 | Narsaq
# Processing Record 393 of set 8 | Anking
# Processing Record 394 of set 8 | Saint Anthony
# Processing Record 395 of set 8 | Mogocha
# Processing Record 396 of set 8 | Basco
# Processing Record 397 of set 8 | Waitati
# Processing Record 398 of set 8 | Salalah
# Processing Record 399 of set 8 | Manaus
# Processing Record 400 of set 8 | Bull Savanna
# Processing Record 401 of set 9 | Margate
# City not found. Skipping...
# Processing Record 403 of set 9 | Evensk
# Processing Record 404 of set 9 | Armidale
# City not found. Skipping...
# Processing Record 406 of set 9 | Abu Samrah
# City not found. Skipping...
# Processing Record 408 of set 9 | Srednekolymsk
# Processing Record 409 of set 9 | Taldan
# Processing Record 410 of set 9 | Lagunas
# Processing Record 411 of set 9 | Garissa
# Processing Record 412 of set 9 | Boende
# Processing Record 413 of set 9 | Touros
# Processing Record 414 of set 9 | Mānsa
# Processing Record 415 of set 9 | Korla
# Processing Record 416 of set 9 | Harnai
# Processing Record 417 of set 9 | Ginir
# Processing Record 418 of set 9 | Babušnica
# Processing Record 419 of set 9 | Camacha
# Processing Record 420 of set 9 | Mikhaylovka
# Processing Record 421 of set 9 | Jeremoabo
# Processing Record 422 of set 9 | Chokurdakh
# Processing Record 423 of set 9 | Dwārka
# Processing Record 424 of set 9 | Hamilton
# Processing Record 425 of set 9 | Nyazepetrovsk
# Processing Record 426 of set 9 | ‘Ewa Beach
# Processing Record 427 of set 9 | Hukuntsi
# Processing Record 428 of set 9 | Pio XII
# Processing Record 429 of set 9 | Jimo
# Processing Record 430 of set 9 | Nizhniy Odes
# Processing Record 431 of set 9 | Vila
# Processing Record 432 of set 9 | De-Kastri
# City not found. Skipping...
# Processing Record 434 of set 9 | Santa Fe
# Processing Record 435 of set 9 | Shirgaon
# Processing Record 436 of set 9 | Nelson Bay
# Processing Record 437 of set 9 | Taksimo
# City not found. Skipping...
# Processing Record 439 of set 9 | Gezing
# Processing Record 440 of set 9 | Belyy Yar
# Processing Record 441 of set 9 | Faranah
# Processing Record 442 of set 9 | Ginda
# Processing Record 443 of set 9 | Westport
# Processing Record 444 of set 9 | Concordia
# Processing Record 445 of set 9 | La Paz
# Processing Record 446 of set 9 | Colares
# Processing Record 447 of set 9 | Sheopur
# Processing Record 448 of set 9 | Vakhrushev
# Processing Record 449 of set 9 | Cairns
# Processing Record 450 of set 9 | Mierlo
# Processing Record 451 of set 10 | Hofn
# Processing Record 452 of set 10 | Taltal
# Processing Record 453 of set 10 | Katherine
# Processing Record 454 of set 10 | Sioux Lookout
# Processing Record 455 of set 10 | Gamba
# Processing Record 456 of set 10 | Yuanping
# Processing Record 457 of set 10 | Esperance
# Processing Record 458 of set 10 | Aland
# Processing Record 459 of set 10 | Cururupu
# Processing Record 460 of set 10 | Omsukchan
# Processing Record 461 of set 10 | Kiryat Gat
# Processing Record 462 of set 10 | Kortkeros
# Processing Record 463 of set 10 | Ipixuna
# Processing Record 464 of set 10 | Ladário
# Processing Record 465 of set 10 | Jining
# Processing Record 466 of set 10 | Comodoro Rivadavia
# Processing Record 467 of set 10 | Sinjai
# Processing Record 468 of set 10 | Fort Dodge
# Processing Record 469 of set 10 | Tselinnoye
# Processing Record 470 of set 10 | Irtyshskiy
# City not found. Skipping...
# Processing Record 472 of set 10 | Semey
# Processing Record 473 of set 10 | Kudahuvadhoo
# Processing Record 474 of set 10 | Bandarbeyla
# Processing Record 475 of set 10 | Lingao
# Processing Record 476 of set 10 | Ballina
# Processing Record 477 of set 10 | Monroe
# Processing Record 478 of set 10 | Ambilobe
# Processing Record 479 of set 10 | Caravelas
# Processing Record 480 of set 10 | Esfarāyen
# Processing Record 481 of set 10 | Pochutla
# Processing Record 482 of set 10 | Charters Towers
# Processing Record 483 of set 10 | Green River
# City not found. Skipping...
# Processing Record 485 of set 10 | Pisco
# Processing Record 486 of set 10 | Liverpool
# Processing Record 487 of set 10 | Yumen
# Processing Record 488 of set 10 | Kaeo
# Processing Record 489 of set 10 | Måløy
# Processing Record 490 of set 10 | Madhipura
# Processing Record 491 of set 10 | Manuk Mangkaw
# Processing Record 492 of set 10 | Hondomachi-hondo
# Processing Record 493 of set 10 | Iisalmi
# Processing Record 494 of set 10 | Antalaha
# Processing Record 495 of set 10 | Sáránd
# Processing Record 496 of set 10 | Batemans Bay
# Processing Record 497 of set 10 | Beringovskiy
# Processing Record 498 of set 10 | Chivay
# Processing Record 499 of set 10 | Carlyle
# Processing Record 500 of set 10 | Ségou
# Processing Record 501 of set 11 | Bereket
# Processing Record 502 of set 11 | Nouadhibou
# Processing Record 503 of set 11 | Iki-Burul
# Processing Record 504 of set 11 | Kiunga
# City not found. Skipping...
# Processing Record 506 of set 11 | Hanyang
# Processing Record 507 of set 11 | Kenai
# Processing Record 508 of set 11 | Ibrā’
# Processing Record 509 of set 11 | Turaif
# Processing Record 510 of set 11 | Dunda
# Processing Record 511 of set 11 | Conceição do Araguaia
# City not found. Skipping...
# Processing Record 513 of set 11 | Yilan
# Processing Record 514 of set 11 | Byron Bay
# Processing Record 515 of set 11 | Muroto-misakicho
# Processing Record 516 of set 11 | Krasnyy
# Processing Record 517 of set 11 | Matara
# Processing Record 518 of set 11 | Vincennes
# Processing Record 519 of set 11 | Bubaque
# Processing Record 520 of set 11 | Limbe
# Processing Record 521 of set 11 | Pulandian
# Processing Record 522 of set 11 | Severomorsk
# Processing Record 523 of set 11 | Denpasar
# City not found. Skipping...
# Processing Record 525 of set 11 | Adrar
# Processing Record 526 of set 11 | Havøysund
# Processing Record 527 of set 11 | Benjamin Constant
# Processing Record 528 of set 11 | Carbonia
# Processing Record 529 of set 11 | Taber
# Processing Record 530 of set 11 | Aykhal
# Processing Record 531 of set 11 | Paamiut
# Processing Record 532 of set 11 | Tapes
# Processing Record 533 of set 11 | Naze
# Processing Record 534 of set 11 | Ushumun
# Processing Record 535 of set 11 | Colesberg
# City not found. Skipping...
# Processing Record 537 of set 11 | São Filipe
# Processing Record 538 of set 11 | Belaya Gora
# Processing Record 539 of set 11 | Ambulu
# Processing Record 540 of set 11 | Nogliki
# Processing Record 541 of set 11 | Auki
# Processing Record 542 of set 11 | Cootamundra
# Processing Record 543 of set 11 | Khandyga
# Processing Record 544 of set 11 | Arlit
# Processing Record 545 of set 11 | Huanren
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 548 of set 11 | Rawson
# Processing Record 549 of set 11 | Makakilo City
# Processing Record 550 of set 11 | Carmelo
# City not found. Skipping...
# Processing Record 552 of set 12 | Banda Aceh
# Processing Record 553 of set 12 | Itarema
# Processing Record 554 of set 12 | Vaitape
# Processing Record 555 of set 12 | Sayansk
# Processing Record 556 of set 12 | Yar-Sale
# Processing Record 557 of set 12 | Karīmganj
# City not found. Skipping...
# Processing Record 559 of set 12 | Vila Velha
# Processing Record 560 of set 12 | Am Timan
# Processing Record 561 of set 12 | Viesca
# Processing Record 562 of set 12 | Kodār
# Processing Record 563 of set 12 | Shimoda
# Processing Record 564 of set 12 | Camaná
# Processing Record 565 of set 12 | Varna
# Processing Record 566 of set 12 | Maltahöhe
# Processing Record 567 of set 12 | Xique-Xique
# Processing Record 568 of set 12 | Harper
# Processing Record 569 of set 12 | Revelstoke
# Processing Record 570 of set 12 | Faanui
# Processing Record 571 of set 12 | Takoradze
# Processing Record 572 of set 12 | Scarborough
# Processing Record 573 of set 12 | Bluefield
# Processing Record 574 of set 12 | San Roque
# Processing Record 575 of set 12 | Ratnagiri
# Processing Record 576 of set 12 | Tilichiki
# Processing Record 577 of set 12 | Atasū
# Processing Record 578 of set 12 | Boda
# Processing Record 579 of set 12 | Labuhan
# Processing Record 580 of set 12 | Sistranda
# Processing Record 581 of set 12 | Sekoma
# Processing Record 582 of set 12 | Yenagoa
# Processing Record 583 of set 12 | Pontianak
# Processing Record 584 of set 12 | Odesskoye
# Processing Record 585 of set 12 | Nuevitas
# Processing Record 586 of set 12 | Zhuanghe
# Processing Record 587 of set 12 | Acajutla
# Processing Record 588 of set 12 | Tupik
# Processing Record 589 of set 12 | Lárdos
# Processing Record 590 of set 12 | Huancavelica
# Processing Record 591 of set 12 | Faxe Ladeplads
# Processing Record 592 of set 12 | Lázaro Cárdenas
# Processing Record 593 of set 12 | Wajima
# City not found. Skipping...
# Processing Record 595 of set 12 | Hay River
# Processing Record 596 of set 12 | Orocué
# Processing Record 597 of set 12 | Alvorada
# Processing Record 598 of set 12 | Marzuq
# Processing Record 599 of set 12 | Bilibino
# Processing Record 600 of set 12 | Santa Isabel Rio Negro
# City not found. Skipping...
# Processing Record 602 of set 13 | San Quintín
# Processing Record 603 of set 13 | Bellavista
# City not found. Skipping...
# Processing Record 605 of set 13 | Misato

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
raw_weather_df=pd.DataFrame(weather_dict)
raw_weather_df.to_csv("output_data/raw_city_data.csv",)
raw_weather_df
# Out:
#                        City  Latitude  Longitude  Max Temperature (Celsius)  \
# 0                 Hithadhoo   -0.6000    73.0833                      28.42
# 1                   Rikitea  -23.1203  -134.9692                      25.31
# 2                   Mataura  -46.1927   168.8643                      10.99
# 3                 Ilulissat   69.2167   -51.1000                     -22.00
# 4                    Dikson   73.5069    80.5464                     -19.37
# ..                      ...       ...        ...                        ...
# 550                Bilibino   68.0546   166.4372                     -18.69
# 551  Santa Isabel Rio Negro   -0.4139   -65.0192                      28.87
# 552             San Quintín   30.4833  -115.9500                      17.79
# 553              Bellavista   -7.0561   -76.5911                      34.00
# 554                  Misato   35.8346   139.8743                       5.56
#
#      Humidity (%)  Cloudiness  Wind Speed (MPH) Country            Date
# 0              71          98              2.81      MV  02/03/21 15:28
# 1              74          10              6.15      PF  02/03/21 15:28
# 2              67          54              2.35      NZ  02/03/21 15:28
# 3              49          20              2.06      GL  02/03/21 15:28
# 4              91         100              8.19      RU  02/03/21 15:28
# ..            ...         ...               ...     ...             ...
# 550            82          97              3.74      RU  02/03/21 15:31
# 551            75          98              1.47      BR  02/03/21 15:31
# 552            72          66              7.46      MX  02/03/21 15:31
# 553            55          40              3.09      PE  02/03/21 15:31
# 554            24           0              2.25      JP  02/03/21 15:31
#
# [555 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
#high_humidity_cities_df
high_humidity_cities_indices=raw_weather_df.loc[raw_weather_df['Humidity (%)']>100].index
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data=raw_weather_df.loc[raw_weather_df['Humidity (%)'] <= 100].reset_index()
clean_city_data.to_csv("output_data/clean_city_data.csv")
clean_city_data
# Out:
#      index                    City  Latitude  Longitude  \
# 0        0               Hithadhoo   -0.6000    73.0833
# 1        1                 Rikitea  -23.1203  -134.9692
# 2        2                 Mataura  -46.1927   168.8643
# 3        3               Ilulissat   69.2167   -51.1000
# 4        4                  Dikson   73.5069    80.5464
# ..     ...                     ...       ...        ...
# 550    550                Bilibino   68.0546   166.4372
# 551    551  Santa Isabel Rio Negro   -0.4139   -65.0192
# 552    552             San Quintín   30.4833  -115.9500
# 553    553              Bellavista   -7.0561   -76.5911
# 554    554                  Misato   35.8346   139.8743
#
#      Max Temperature (Celsius)  Humidity (%)  Cloudiness  Wind Speed (MPH)  \
# 0                        28.42            71          98              2.81
# 1                        25.31            74          10              6.15
# 2                        10.99            67          54              2.35
# 3                       -22.00            49          20              2.06
# 4                       -19.37            91         100              8.19
# ..                         ...           ...         ...               ...
# 550                     -18.69            82          97              3.74
# 551                      28.87            75          98              1.47
# 552                      17.79            72          66              7.46
# 553                      34.00            55          40              3.09
# 554                       5.56            24           0              2.25
#
#     Country            Date
# 0        MV  02/03/21 15:28
# 1        PF  02/03/21 15:28
# 2        NZ  02/03/21 15:28
# 3        GL  02/03/21 15:28
# 4        RU  02/03/21 15:28
# ..      ...             ...
# 550      RU  02/03/21 15:31
# 551      BR  02/03/21 15:31
# 552      MX  02/03/21 15:31
# 553      PE  02/03/21 15:31
# 554      JP  02/03/21 15:31
#
# [555 rows x 10 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
date= clean_city_data.Date.tolist()[0][0:8]
ax1 = clean_city_data.plot.scatter(x="Latitude", y="Max Temperature (Celsius)")
ax1.set_title(f"City Latitude vs Max Temperature ({date})")
ax1.grid(True)
plt.savefig(f"output_data/City_Latitude_vs_Max_Temperature_Scatter_Plot.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
ax2 = clean_city_data.plot.scatter(x="Latitude", y="Humidity (%)")
ax2.set_title(f"City Latitude vs Humidity ({date})")
ax2.grid(True)
plt.savefig(f"output_data/City_Latitude_vs_Humidity_Scatter_Plot.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
ax3 = clean_city_data.plot.scatter(x="Latitude", y="Cloudiness")
ax3.set_title(f"City Latitude vs Cloudiness ({date})")
ax3.grid(True)
plt.savefig(f"output_data/City_Latitude_vs_Cloudiness_Scatter_Plot.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
ax4 = clean_city_data.plot.scatter(x="Latitude", y="Wind Speed (MPH)")
ax4.set_title(f"City Latitude vs Wind Speed ({date})")
ax4.grid(True)
plt.savefig(f"output_data/City_Latitude_vs_Wind_Speed_Scatter_Plot.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
