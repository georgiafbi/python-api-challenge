# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
# Import API key
from api_keys import weather_api_key
from datetime import datetime

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
city=[]
lat=[]
lng=[]
humidity=[]
clouds=[]
windspeed=[]
country=[]
date=[]
max_temp=[]
weather_dict ={"City": city,"Latitude":lat,"Longitude":lng,"Max Temperature (Celsius)": max_temp,"Humidity (%)":humidity,"Cloudiness (%)":clouds,"Wind Speed (mph)":windspeed,"Country": country,"Date":date}
j=1
print("Beginning Data Retrieval\n-----------------------------")
#Build query url
for i in range(len(cities)):
    url=f'https://api.openweathermap.org/data/2.5/weather?q={cities[i]}&appid={weather_api_key}'
    #get weather data
    weather_response = requests.get(url)
    weather_json=weather_response.json()
    try:
        city.append(weather_json['name'])
        lat.append(weather_json['coord']['lat'])
        lng.append(weather_json['coord']['lon'])
        max_temp.append(round(weather_json['main']['temp_max']-273.15,2))
        humidity.append(weather_json['main']['humidity'])
        clouds.append(weather_json['clouds']['all'])
        windspeed.append(weather_json['wind']['speed'])
        country.append(weather_json['sys']['country'])
        date.append(time.strftime('%D %H:%M', time.localtime(int(weather_json['dt']))))
        if i == j*50:
            j+=1
        print(f"Processing Record {i+1} of set {j} | {city[-1]}")
    except KeyError:
        if i == j*50:
            j+=1
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of set 1 | Blagoveshchenka
# Processing Record 2 of set 1 | Northport
# Processing Record 3 of set 1 | Talnakh
# Processing Record 4 of set 1 | Saint Anthony
# Processing Record 5 of set 1 | Albany
# Processing Record 6 of set 1 | Qax
# Processing Record 7 of set 1 | Port Alfred
# Processing Record 8 of set 1 | Thunder Bay
# Processing Record 9 of set 1 | Hobart
# Processing Record 10 of set 1 | Mataura
# Processing Record 11 of set 1 | Bluff
# City not found. Skipping...
# Processing Record 13 of set 1 | St. George's
# Processing Record 14 of set 1 | Gubkinskiy
# City not found. Skipping...
# Processing Record 16 of set 1 | Hong Kong
# Processing Record 17 of set 1 | Bilma
# Processing Record 18 of set 1 | Havre-St-Pierre
# Processing Record 19 of set 1 | Souillac
# Processing Record 20 of set 1 | Caravelas
# Processing Record 21 of set 1 | Rikitea
# Processing Record 22 of set 1 | Husavik
# Processing Record 23 of set 1 | Qaanaaq
# Processing Record 24 of set 1 | Bethel
# Processing Record 25 of set 1 | Sittwe
# Processing Record 26 of set 1 | Punta Arenas
# Processing Record 27 of set 1 | Iqaluit
# Processing Record 28 of set 1 | Ginda
# Processing Record 29 of set 1 | Ribeira Grande
# Processing Record 30 of set 1 | Mponela
# Processing Record 31 of set 1 | Province of Mantua
# Processing Record 32 of set 1 | Kaitangata
# Processing Record 33 of set 1 | Atuona
# Processing Record 34 of set 1 | Jamestown
# Processing Record 35 of set 1 | Fortuna
# Processing Record 36 of set 1 | Campbell River
# Processing Record 37 of set 1 | Vaini
# Processing Record 38 of set 1 | Saint Paul Harbor
# Processing Record 39 of set 1 | Ushuaia
# Processing Record 40 of set 1 | Barrow
# Processing Record 41 of set 1 | Bocaiúva
# Processing Record 42 of set 1 | Shitanjing
# City not found. Skipping...
# Processing Record 44 of set 1 | Mae Sai
# Processing Record 45 of set 1 | Hermanus
# Processing Record 46 of set 1 | Upernavik
# Processing Record 47 of set 1 | New Norfolk
# City not found. Skipping...
# Processing Record 49 of set 1 | San Cristobal
# Processing Record 50 of set 1 | Esim
# Processing Record 51 of set 2 | Isangel
# Processing Record 52 of set 2 | Corn Island
# Processing Record 53 of set 2 | Carnarvon
# Processing Record 54 of set 2 | Poum
# Processing Record 55 of set 2 | Bintulu
# Processing Record 56 of set 2 | Lüderitz
# Processing Record 57 of set 2 | Laguna
# Processing Record 58 of set 2 | Mattru
# Processing Record 59 of set 2 | Olinda
# Processing Record 60 of set 2 | College
# Processing Record 61 of set 2 | Kavieng
# Processing Record 62 of set 2 | Los Llanos de Aridane
# Processing Record 63 of set 2 | San Patricio
# Processing Record 64 of set 2 | Esperance
# Processing Record 65 of set 2 | Kloulklubed
# Processing Record 66 of set 2 | Longyearbyen
# Processing Record 67 of set 2 | Podor
# Processing Record 68 of set 2 | Khovu-Aksy
# Processing Record 69 of set 2 | Karratha
# City not found. Skipping...
# Processing Record 71 of set 2 | Port Hedland
# Processing Record 72 of set 2 | Arlit
# City not found. Skipping...
# Processing Record 74 of set 2 | Cape Town
# Processing Record 75 of set 2 | Qaqortoq
# Processing Record 76 of set 2 | Itarema
# Processing Record 77 of set 2 | Severo-Kuril'sk
# City not found. Skipping...
# Processing Record 79 of set 2 | Vostok
# Processing Record 80 of set 2 | Hasaki
# Processing Record 81 of set 2 | Broken Hill
# Processing Record 82 of set 2 | Airai
# Processing Record 83 of set 2 | Chui
# Processing Record 84 of set 2 | Vardø
# City not found. Skipping...
# Processing Record 86 of set 2 | Bubaque
# Processing Record 87 of set 2 | Bakchar
# Processing Record 88 of set 2 | Khatanga
# Processing Record 89 of set 2 | Strelka
# Processing Record 90 of set 2 | Rio Grande
# Processing Record 91 of set 2 | Kirakira
# Processing Record 92 of set 2 | Clovis
# Processing Record 93 of set 2 | Katsuura
# City not found. Skipping...
# Processing Record 95 of set 2 | Hilo
# Processing Record 96 of set 2 | Skjervøy
# Processing Record 97 of set 2 | Magadan
# City not found. Skipping...
# Processing Record 99 of set 2 | Puerto Ayora
# Processing Record 100 of set 2 | Salalah
# Processing Record 101 of set 3 | Athabasca
# Processing Record 102 of set 3 | Baykit
# Processing Record 103 of set 3 | Busselton
# Processing Record 104 of set 3 | Vila Franca do Campo
# Processing Record 105 of set 3 | Tiksi
# Processing Record 106 of set 3 | Iracoubo
# Processing Record 107 of set 3 | Yerbogachën
# Processing Record 108 of set 3 | Lázaro Cárdenas
# Processing Record 109 of set 3 | Mana
# Processing Record 110 of set 3 | Sainte-Anne-des-Monts
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 113 of set 3 | Hithadhoo
# Processing Record 114 of set 3 | Pevek
# Processing Record 115 of set 3 | Havøysund
# Processing Record 116 of set 3 | Mount Isa
# Processing Record 117 of set 3 | Goderich
# Processing Record 118 of set 3 | Dondaicha
# Processing Record 119 of set 3 | Tshikapa
# Processing Record 120 of set 3 | Saint-Philippe
# Processing Record 121 of set 3 | Carbonia
# Processing Record 122 of set 3 | Kapaa
# Processing Record 123 of set 3 | Takaka
# Processing Record 124 of set 3 | Røros
# Processing Record 125 of set 3 | Puerto Escondido
# Processing Record 126 of set 3 | Belyy Yar
# Processing Record 127 of set 3 | Hofn
# Processing Record 128 of set 3 | Pisco
# Processing Record 129 of set 3 | Port Lincoln
# Processing Record 130 of set 3 | Udachny
# Processing Record 131 of set 3 | Mar del Plata
# Processing Record 132 of set 3 | Mango
# City not found. Skipping...
# Processing Record 134 of set 3 | Río Gallegos
# Processing Record 135 of set 3 | Arrondissement de Saint-Denis
# Processing Record 136 of set 3 | Bredasdorp
# City not found. Skipping...
# Processing Record 138 of set 3 | Cidreira
# Processing Record 139 of set 3 | Jasper
# Processing Record 140 of set 3 | Cabo San Lucas
# Processing Record 141 of set 3 | Dera Bugti
# Processing Record 142 of set 3 | Avarua
# Processing Record 143 of set 3 | Sitka
# Processing Record 144 of set 3 | Arraial do Cabo
# Processing Record 145 of set 3 | Emerald
# Processing Record 146 of set 3 | Sorong
# Processing Record 147 of set 3 | Gilgit
# Processing Record 148 of set 3 | Dikson
# Processing Record 149 of set 3 | Port Elizabeth
# City not found. Skipping...
# Processing Record 151 of set 4 | Marrakesh
# City not found. Skipping...
# Processing Record 153 of set 4 | Inta
# Processing Record 154 of set 4 | Rurrenabaque
# Processing Record 155 of set 4 | Miraflores
# Processing Record 156 of set 4 | Nikolskoye
# Processing Record 157 of set 4 | Saldanha
# Processing Record 158 of set 4 | Nuuk
# Processing Record 159 of set 4 | Srednekolymsk
# Processing Record 160 of set 4 | Norman Wells
# Processing Record 161 of set 4 | Gouré
# Processing Record 162 of set 4 | Shingū
# Processing Record 163 of set 4 | Constitución
# City not found. Skipping...
# Processing Record 165 of set 4 | Thompson
# Processing Record 166 of set 4 | Prince Albert
# Processing Record 167 of set 4 | La Libertad
# Processing Record 168 of set 4 | Codrington
# City not found. Skipping...
# Processing Record 170 of set 4 | Sobolevo
# Processing Record 171 of set 4 | Gerāsh
# Processing Record 172 of set 4 | Yellowknife
# Processing Record 173 of set 4 | Manuel Roxas
# Processing Record 174 of set 4 | Conakry
# Processing Record 175 of set 4 | Léo
# City not found. Skipping...
# Processing Record 177 of set 4 | Buala
# Processing Record 178 of set 4 | Torbay
# Processing Record 179 of set 4 | Ystad
# Processing Record 180 of set 4 | Naze
# Processing Record 181 of set 4 | Gōtsuchō
# Processing Record 182 of set 4 | George Town
# Processing Record 183 of set 4 | Prince George
# Processing Record 184 of set 4 | Bilibino
# Processing Record 185 of set 4 | Castlegar
# Processing Record 186 of set 4 | Rantauprapat
# Processing Record 187 of set 4 | Nibbar
# Processing Record 188 of set 4 | Port Hardy
# Processing Record 189 of set 4 | São Joaquim
# Processing Record 190 of set 4 | Tasiilaq
# Processing Record 191 of set 4 | Caraballeda
# Processing Record 192 of set 4 | Anadyr
# Processing Record 193 of set 4 | Galiākot
# Processing Record 194 of set 4 | Escanaba
# Processing Record 195 of set 4 | Ponta do Sol
# Processing Record 196 of set 4 | Dwārka
# Processing Record 197 of set 4 | Barra dos Coqueiros
# Processing Record 198 of set 4 | Scăeşti
# Processing Record 199 of set 4 | Laas
# Processing Record 200 of set 4 | Lorengau
# City not found. Skipping...
# Processing Record 202 of set 5 | Tuktoyaktuk
# Processing Record 203 of set 5 | Moussoro
# Processing Record 204 of set 5 | Russell
# Processing Record 205 of set 5 | Pangnirtung
# Processing Record 206 of set 5 | Umba
# Processing Record 207 of set 5 | East London
# Processing Record 208 of set 5 | Mafra
# Processing Record 209 of set 5 | Oranjemund
# Processing Record 210 of set 5 | Ipilan
# Processing Record 211 of set 5 | Turbat
# Processing Record 212 of set 5 | Plettenberg Bay
# Processing Record 213 of set 5 | Wau
# Processing Record 214 of set 5 | Okhotsk
# City not found. Skipping...
# Processing Record 216 of set 5 | Bengkulu
# Processing Record 217 of set 5 | Ajdabiya
# Processing Record 218 of set 5 | Bam
# Processing Record 219 of set 5 | Ilhabela
# Processing Record 220 of set 5 | Jaisalmer
# Processing Record 221 of set 5 | Kalanguy
# Processing Record 222 of set 5 | Pontal do Paraná
# Processing Record 223 of set 5 | Raja
# Processing Record 224 of set 5 | Panzhihua
# Processing Record 225 of set 5 | Saint George
# Processing Record 226 of set 5 | Castro
# City not found. Skipping...
# Processing Record 228 of set 5 | Geraldton
# Processing Record 229 of set 5 | Xiuyan
# Processing Record 230 of set 5 | Dunedin
# Processing Record 231 of set 5 | Vadlapūdi
# Processing Record 232 of set 5 | Vao
# Processing Record 233 of set 5 | Kondinskoye
# Processing Record 234 of set 5 | San Joaquin
# Processing Record 235 of set 5 | Riverton
# Processing Record 236 of set 5 | Khovd
# Processing Record 237 of set 5 | Tiznit Province
# City not found. Skipping...
# Processing Record 239 of set 5 | Madison
# Processing Record 240 of set 5 | Bloomington
# City not found. Skipping...
# Processing Record 242 of set 5 | Oshawa
# Processing Record 243 of set 5 | Lima
# Processing Record 244 of set 5 | São Filipe
# Processing Record 245 of set 5 | Butaritari
# Processing Record 246 of set 5 | Bad Orb
# Processing Record 247 of set 5 | Fuerte Olimpo
# Processing Record 248 of set 5 | Turukhansk
# Processing Record 249 of set 5 | Ahipara
# Processing Record 250 of set 5 | Mackay
# Processing Record 251 of set 6 | Bath
# Processing Record 252 of set 6 | San Quintín
# Processing Record 253 of set 6 | Alta
# Processing Record 254 of set 6 | Viedma
# Processing Record 255 of set 6 | Sinnamary
# Processing Record 256 of set 6 | Qui Nhon
# Processing Record 257 of set 6 | Sergeevka
# Processing Record 258 of set 6 | Sortland
# Processing Record 259 of set 6 | Lubumbashi
# Processing Record 260 of set 6 | Skaerbaek
# Processing Record 261 of set 6 | Teya
# Processing Record 262 of set 6 | Mwinilunga
# Processing Record 263 of set 6 | Tautira
# Processing Record 264 of set 6 | Najrān
# Processing Record 265 of set 6 | Urucará
# Processing Record 266 of set 6 | Sept-Îles
# Processing Record 267 of set 6 | Provideniya
# Processing Record 268 of set 6 | Teotitlán
# Processing Record 269 of set 6 | Tindivanam
# Processing Record 270 of set 6 | Saint-Joseph
# Processing Record 271 of set 6 | Rincon
# Processing Record 272 of set 6 | Alice Springs
# Processing Record 273 of set 6 | Dauphin
# Processing Record 274 of set 6 | Elverum
# City not found. Skipping...
# Processing Record 276 of set 6 | Kattivākkam
# Processing Record 277 of set 6 | Kushima
# Processing Record 278 of set 6 | Veselynove
# Processing Record 279 of set 6 | Albemarle
# Processing Record 280 of set 6 | Tezu
# Processing Record 281 of set 6 | Nanortalik
# Processing Record 282 of set 6 | Huanren
# Processing Record 283 of set 6 | Carora
# Processing Record 284 of set 6 | Zalţan
# Processing Record 285 of set 6 | Cancún
# Processing Record 286 of set 6 | Dingle
# Processing Record 287 of set 6 | Assiut
# Processing Record 288 of set 6 | Kyren
# Processing Record 289 of set 6 | Narsaq
# Processing Record 290 of set 6 | Asău
# City not found. Skipping...
# Processing Record 292 of set 6 | Enshi
# Processing Record 293 of set 6 | Kousséri
# Processing Record 294 of set 6 | Flinders
# Processing Record 295 of set 6 | Saskylakh
# Processing Record 296 of set 6 | Lebu
# Processing Record 297 of set 6 | Labé
# Processing Record 298 of set 6 | Maniitsoq
# Processing Record 299 of set 6 | Vanavara
# Processing Record 300 of set 6 | Yaguajay
# Processing Record 301 of set 7 | Kayerkan
# City not found. Skipping...
# Processing Record 303 of set 7 | The Valley
# Processing Record 304 of set 7 | Te Anau
# Processing Record 305 of set 7 | General Roca
# Processing Record 306 of set 7 | Lagoa
# Processing Record 307 of set 7 | Nokaneng
# Processing Record 308 of set 7 | Kapit
# Processing Record 309 of set 7 | Jilemnice
# Processing Record 310 of set 7 | Corrente
# Processing Record 311 of set 7 | San Andrés
# Processing Record 312 of set 7 | Malindi
# Processing Record 313 of set 7 | Stokmarknes
# Processing Record 314 of set 7 | Meadow Lake
# Processing Record 315 of set 7 | Nhulunbuy
# Processing Record 316 of set 7 | Pamplona
# Processing Record 317 of set 7 | Nemuro
# Processing Record 318 of set 7 | Korla
# Processing Record 319 of set 7 | Chokurdakh
# Processing Record 320 of set 7 | Klaksvík
# Processing Record 321 of set 7 | Winneba
# Processing Record 322 of set 7 | Umluj
# Processing Record 323 of set 7 | Świdwin
# Processing Record 324 of set 7 | Praia
# Processing Record 325 of set 7 | Cap-aux-Meules
# Processing Record 326 of set 7 | Fomboni
# Processing Record 327 of set 7 | Caluquembe
# Processing Record 328 of set 7 | Hammerfest
# Processing Record 329 of set 7 | Rosamorada
# Processing Record 330 of set 7 | Ca Mau
# Processing Record 331 of set 7 | Yarensk
# Processing Record 332 of set 7 | Rawson
# Processing Record 333 of set 7 | Japura
# Processing Record 334 of set 7 | Chahal Guatemala
# Processing Record 335 of set 7 | Tiarei
# Processing Record 336 of set 7 | Nantucket
# Processing Record 337 of set 7 | Faanui
# Processing Record 338 of set 7 | Chicama
# Processing Record 339 of set 7 | Ilulissat
# Processing Record 340 of set 7 | Guerrero Negro
# Processing Record 341 of set 7 | Uddevalla
# Processing Record 342 of set 7 | Kendari
# Processing Record 343 of set 7 | Mahébourg
# Processing Record 344 of set 7 | Trincomalee
# Processing Record 345 of set 7 | Langham
# Processing Record 346 of set 7 | Kharp
# Processing Record 347 of set 7 | Mossamedes
# Processing Record 348 of set 7 | Mashhad
# Processing Record 349 of set 7 | Ignacio Zaragoza
# Processing Record 350 of set 7 | Merritt
# Processing Record 351 of set 8 | Deputatsky
# Processing Record 352 of set 8 | Cascais
# Processing Record 353 of set 8 | Roald
# Processing Record 354 of set 8 | Vila Real
# Processing Record 355 of set 8 | Colorado
# Processing Record 356 of set 8 | Praia
# Processing Record 357 of set 8 | Belaya Gora
# Processing Record 358 of set 8 | Gorontalo
# Processing Record 359 of set 8 | Bambari
# Processing Record 360 of set 8 | Mount Darwin
# Processing Record 361 of set 8 | Sibolga
# Processing Record 362 of set 8 | Coyhaique
# Processing Record 363 of set 8 | Vieques
# Processing Record 364 of set 8 | São João de Pirabas
# Processing Record 365 of set 8 | Örnsköldsvik
# City not found. Skipping...
# Processing Record 367 of set 8 | Ubari
# Processing Record 368 of set 8 | Nova Venécia
# Processing Record 369 of set 8 | Kayes
# Processing Record 370 of set 8 | Mitsamiouli
# Processing Record 371 of set 8 | Saint-Junien
# Processing Record 372 of set 8 | Billings Metropolitan Area
# Processing Record 373 of set 8 | Hatillo
# Processing Record 374 of set 8 | Sotouboua
# Processing Record 375 of set 8 | Kruisfontein
# Processing Record 376 of set 8 | Tarauacá
# Processing Record 377 of set 8 | Linxia Chengguanzhen
# Processing Record 378 of set 8 | Kavaratti
# Processing Record 379 of set 8 | Bambous Virieux
# Processing Record 380 of set 8 | Lodwar
# Processing Record 381 of set 8 | Kibala
# Processing Record 382 of set 8 | Lovozero
# Processing Record 383 of set 8 | Le Port
# Processing Record 384 of set 8 | North Bend
# Processing Record 385 of set 8 | Brae
# Processing Record 386 of set 8 | Amurzet
# City not found. Skipping...
# Processing Record 388 of set 8 | Santoña
# Processing Record 389 of set 8 | Arrondissement de Lons-le-Saunier
# Processing Record 390 of set 8 | Vryburg
# Processing Record 391 of set 8 | Muli
# Processing Record 392 of set 8 | Ayan
# Processing Record 393 of set 8 | Lamu
# Processing Record 394 of set 8 | São Francisco de Assis
# Processing Record 395 of set 8 | Gáldar
# Processing Record 396 of set 8 | Shymkent
# Processing Record 397 of set 8 | Ancud
# Processing Record 398 of set 8 | Poopó
# Processing Record 399 of set 8 | Buraidah
# Processing Record 400 of set 8 | Nouadhibou
# Processing Record 401 of set 9 | Meulaboh
# Processing Record 402 of set 9 | Imeni Poliny Osipenko
# Processing Record 403 of set 9 | Yanzhou
# Processing Record 404 of set 9 | Mamit
# Processing Record 405 of set 9 | Tierra Nueva
# Processing Record 406 of set 9 | Alexandria
# Processing Record 407 of set 9 | Kahului
# Processing Record 408 of set 9 | Chengde
# Processing Record 409 of set 9 | Alofi
# Processing Record 410 of set 9 | Altay
# Processing Record 411 of set 9 | Ishim
# Processing Record 412 of set 9 | Haukipudas
# Processing Record 413 of set 9 | Adrar
# Processing Record 414 of set 9 | Yuxia
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 417 of set 9 | Pueblo
# Processing Record 418 of set 9 | Sarkand
# Processing Record 419 of set 9 | Moanda
# Processing Record 420 of set 9 | Marystown
# Processing Record 421 of set 9 | Mercedes
# Processing Record 422 of set 9 | Aracati
# Processing Record 423 of set 9 | Ballina
# Processing Record 424 of set 9 | Bathsheba
# Processing Record 425 of set 9 | Kieta
# Processing Record 426 of set 9 | Tura
# Processing Record 427 of set 9 | Riberalta
# Processing Record 428 of set 9 | Acapulco de Juárez
# Processing Record 429 of set 9 | Clyde River
# Processing Record 430 of set 9 | Villa Carlos Paz
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 433 of set 9 | Kostomuksha
# Processing Record 434 of set 9 | Magistral'nyy
# Processing Record 435 of set 9 | Labuhan
# City not found. Skipping...
# Processing Record 437 of set 9 | Yulara
# Processing Record 438 of set 9 | Ngunguru
# Processing Record 439 of set 9 | Cherskiy
# Processing Record 440 of set 9 | Chunhuhub
# Processing Record 441 of set 9 | Monywa
# Processing Record 442 of set 9 | Walvis Bay
# Processing Record 443 of set 9 | Abhā
# Processing Record 444 of set 9 | Toora-Khem
# Processing Record 445 of set 9 | Saquena
# Processing Record 446 of set 9 | Dholka
# City not found. Skipping...
# Processing Record 448 of set 9 | Fasa
# Processing Record 449 of set 9 | Dicabisagan
# Processing Record 450 of set 9 | São João da Barra
# Processing Record 451 of set 10 | Gao
# Processing Record 452 of set 10 | Banda Aceh
# Processing Record 453 of set 10 | Portland
# Processing Record 454 of set 10 | Coahuayana Viejo
# Processing Record 455 of set 10 | Baruun-Urt
# Processing Record 456 of set 10 | Lata
# Processing Record 457 of set 10 | Diffa
# Processing Record 458 of set 10 | Morros
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 461 of set 10 | Damietta
# Processing Record 462 of set 10 | Baiyin
# Processing Record 463 of set 10 | Port Blair
# Processing Record 464 of set 10 | Baracoa
# Processing Record 465 of set 10 | Ambilobe
# Processing Record 466 of set 10 | Piaçabuçu
# City not found. Skipping...
# Processing Record 468 of set 10 | Cañon City
# Processing Record 469 of set 10 | Listvyanskiy
# Processing Record 470 of set 10 | Bud
# Processing Record 471 of set 10 | Storforshei
# Processing Record 472 of set 10 | Calabozo
# Processing Record 473 of set 10 | Galesong
# Processing Record 474 of set 10 | Tilichiki
# Processing Record 475 of set 10 | Avera
# Processing Record 476 of set 10 | Luján
# Processing Record 477 of set 10 | Alice
# Processing Record 478 of set 10 | San Vicente
# Processing Record 479 of set 10 | Beloeil
# Processing Record 480 of set 10 | Lakes Entrance
# Processing Record 481 of set 10 | Zliten
# City not found. Skipping...
# Processing Record 483 of set 10 | Taoudenni
# Processing Record 484 of set 10 | Rome
# Processing Record 485 of set 10 | Healdsburg
# Processing Record 486 of set 10 | Newport Beach
# Processing Record 487 of set 10 | Birao
# Processing Record 488 of set 10 | Haines Junction
# Processing Record 489 of set 10 | Cabedelo
# Processing Record 490 of set 10 | Galle
# Processing Record 491 of set 10 | Tucupita
# Processing Record 492 of set 10 | Krasnosel'kup
# Processing Record 493 of set 10 | Graciano Sánchez
# Processing Record 494 of set 10 | Santana do Livramento
# Processing Record 495 of set 10 | Llata
# Processing Record 496 of set 10 | Mahanje
# City not found. Skipping...
# Processing Record 498 of set 10 | Wildwood
# Processing Record 499 of set 10 | Senno
# Processing Record 500 of set 10 | Bull Savanna
# Processing Record 501 of set 11 | Gwadar
# Processing Record 502 of set 11 | Darnah
# Processing Record 503 of set 11 | George Town
# Processing Record 504 of set 11 | Half Moon Bay
# Processing Record 505 of set 11 | Lebanon
# Processing Record 506 of set 11 | Auki
# Processing Record 507 of set 11 | Gravdal
# Processing Record 508 of set 11 | Krasnoarmeysk
# Processing Record 509 of set 11 | Margate
# Processing Record 510 of set 11 | Grand Forks
# Processing Record 511 of set 11 | Bandarbeyla
# City not found. Skipping...
# Processing Record 513 of set 11 | Coos Bay
# Processing Record 514 of set 11 | Banepā
# City not found. Skipping...
# Processing Record 516 of set 11 | Chekmagush
# Processing Record 517 of set 11 | Vega de Alatorre
# Processing Record 518 of set 11 | Mahon
# Processing Record 519 of set 11 | Ha Giang
# Processing Record 520 of set 11 | Setermoen
# Processing Record 521 of set 11 | Sakakah
# Processing Record 522 of set 11 | Ingham
# Processing Record 523 of set 11 | Egvekinot
# Processing Record 524 of set 11 | Celestún
# Processing Record 525 of set 11 | Pangody
# Processing Record 526 of set 11 | Kulhudhuffushi
# Processing Record 527 of set 11 | Touros
# Processing Record 528 of set 11 | Emba
# Processing Record 529 of set 11 | Vanimo
# Processing Record 530 of set 11 | Ushtobe
# Processing Record 531 of set 11 | Kirkuk
# Processing Record 532 of set 11 | La Palma
# Processing Record 533 of set 11 | Kathmandu
# Processing Record 534 of set 11 | Kargasok
# Processing Record 535 of set 11 | João Neiva
# Processing Record 536 of set 11 | Puro
# City not found. Skipping...
# Processing Record 538 of set 11 | Chake Chake
# Processing Record 539 of set 11 | Departamento de Maldonado
# Processing Record 540 of set 11 | Gaya
# Processing Record 541 of set 11 | Marsaxlokk
# Processing Record 542 of set 11 | Faya
# Processing Record 543 of set 11 | Bahía Honda
# Processing Record 544 of set 11 | Umm Kaddadah
# Processing Record 545 of set 11 | Maceió
# Processing Record 546 of set 11 | Plátanos
# Processing Record 547 of set 11 | Zhezkazgan
# City not found. Skipping...
# Processing Record 549 of set 11 | San Juan
# Processing Record 550 of set 11 | Champasak
# Processing Record 551 of set 12 | Hervey Bay
# Processing Record 552 of set 12 | Namuac
# City not found. Skipping...
# Processing Record 554 of set 12 | Senneterre
# Processing Record 555 of set 12 | Cap Malheureux
# Processing Record 556 of set 12 | Gigmoto
# Processing Record 557 of set 12 | Naryan-Mar
# Processing Record 558 of set 12 | Maur
# Processing Record 559 of set 12 | Porto Walter
# Processing Record 560 of set 12 | Vila
# Processing Record 561 of set 12 | Marawi
# Processing Record 562 of set 12 | Izumo
# Processing Record 563 of set 12 | Byron Bay
# Processing Record 564 of set 12 | Nome
# Processing Record 565 of set 12 | Manono
# Processing Record 566 of set 12 | Road Town
# Processing Record 567 of set 12 | Emporia
# Processing Record 568 of set 12 | Fort-Shevchenko
# Processing Record 569 of set 12 | Barra Patuca
# Processing Record 570 of set 12 | Idrinskoye
# Processing Record 571 of set 12 | Huntsville
# Processing Record 572 of set 12 | Champerico
# Processing Record 573 of set 12 | Tadine
# Processing Record 574 of set 12 | Riyadh
# Processing Record 575 of set 12 | Kiruna
# Processing Record 576 of set 12 | Evensk
# Processing Record 577 of set 12 | Pesaro
# Processing Record 578 of set 12 | Comodoro Rivadavia
# Processing Record 579 of set 12 | Tocopilla
# Processing Record 580 of set 12 | Mount Gambier
# Processing Record 581 of set 12 | Rio de Janeiro
# Processing Record 582 of set 12 | Shakiso
# Processing Record 583 of set 12 | Wanning
# Processing Record 584 of set 12 | Thinadhoo
# Processing Record 585 of set 12 | Mogadishu
# City not found. Skipping...
# Processing Record 587 of set 12 | Padang
# Processing Record 588 of set 12 | Leningradskiy
# Processing Record 589 of set 12 | Gamba
# Processing Record 590 of set 12 | Sambava
# Processing Record 591 of set 12 | Colesberg
# Processing Record 592 of set 12 | Yeniseysk
# Processing Record 593 of set 12 | Zaragoza
# Processing Record 594 of set 12 | Tay Ninh
# Processing Record 595 of set 12 | City of San Pedro
# Processing Record 596 of set 12 | Lavrentiya
# Processing Record 597 of set 12 | Iquitos
# Processing Record 598 of set 12 | Shimoni
# Processing Record 599 of set 12 | Dubovka
# Processing Record 600 of set 12 | Gizo Government Station
# Processing Record 601 of set 13 | Qiqihar
# Processing Record 602 of set 13 | Poronaysk
# Processing Record 603 of set 13 | Miranda
# Processing Record 604 of set 13 | Ponta Delgada
# Processing Record 605 of set 13 | Presidencia Roque Sáenz Peña
# Processing Record 606 of set 13 | Yumen
# Processing Record 607 of set 13 | Muroto-misakicho
# Processing Record 608 of set 13 | La Grande
# Processing Record 609 of set 13 | Waipawa
# Processing Record 610 of set 13 | Uptar
# Processing Record 611 of set 13 | Puerto Baquerizo Moreno
# Processing Record 612 of set 13 | Pocrí
# City not found. Skipping...
# Processing Record 614 of set 13 | Durban
# City not found. Skipping...
# Processing Record 616 of set 13 | Bad Krozingen
# Processing Record 617 of set 13 | Tanhaçu
# Processing Record 618 of set 13 | Oudtshoorn

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
raw_weather_df=pd.DataFrame(weather_dict)
raw_weather_df.to_csv("output_data/raw_city_data.csv",)
raw_weather_df
# Out:
#                 City  Latitude  Longitude  Max Temperature (Celsius)  \
# 0    Blagoveshchenka   52.8333    79.8667                      -3.97
# 1          Northport   33.2290   -87.5772                       1.00
# 2            Talnakh   69.4865    88.3972                     -28.07
# 3      Saint Anthony   45.0205   -93.2180                       0.00
# 4             Albany   42.6001   -73.9662                      -2.22
# ..               ...       ...        ...                        ...
# 565            Pocrí    8.2667   -80.5500                      25.29
# 566           Durban  -29.8579    31.0292                      26.11
# 567    Bad Krozingen   47.9167     7.7000                       7.22
# 568          Tanhaçu  -14.0214   -41.2481                      20.36
# 569       Oudtshoorn  -33.5907    22.2014                      18.00
#
#      Humidity (%)  Cloudiness (%)  Wind Speed (mph) Country            Date
# 0              97             100              2.50      RU  02/04/21 01:27
# 1              80               1              2.06      US  02/04/21 01:27
# 2              86              98              1.88      RU  02/04/21 01:27
# 3              80              90              5.14      US  02/04/21 01:27
# 4              82              92              4.66      US  02/04/21 01:23
# ..            ...             ...               ...     ...             ...
# 565            76              38              5.85      PA  02/04/21 01:29
# 566            83               0              1.54      ZA  02/04/21 01:29
# 567            84              56              0.89      DE  02/04/21 01:29
# 568            95              64              1.25      BR  02/04/21 01:29
# 569            88              20              2.06      ZA  02/04/21 01:25
#
# [570 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
#high_humidity_cities_df
high_humidity_cities_indices=raw_weather_df.loc[raw_weather_df['Humidity (%)']>100].index
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data=raw_weather_df.loc[raw_weather_df['Humidity (%)'] <= 100].reset_index()
clean_city_data.to_csv("output_data/clean_city_data.csv")
clean_city_data
# Out:
#      index             City  Latitude  Longitude  Max Temperature (Celsius)  \
# 0        0  Blagoveshchenka   52.8333    79.8667                      -3.97
# 1        1        Northport   33.2290   -87.5772                       1.00
# 2        2          Talnakh   69.4865    88.3972                     -28.07
# 3        3    Saint Anthony   45.0205   -93.2180                       0.00
# 4        4           Albany   42.6001   -73.9662                      -2.22
# ..     ...              ...       ...        ...                        ...
# 565    565            Pocrí    8.2667   -80.5500                      25.29
# 566    566           Durban  -29.8579    31.0292                      26.11
# 567    567    Bad Krozingen   47.9167     7.7000                       7.22
# 568    568          Tanhaçu  -14.0214   -41.2481                      20.36
# 569    569       Oudtshoorn  -33.5907    22.2014                      18.00
#
#      Humidity (%)  Cloudiness (%)  Wind Speed (mph) Country            Date
# 0              97             100              2.50      RU  02/04/21 01:27
# 1              80               1              2.06      US  02/04/21 01:27
# 2              86              98              1.88      RU  02/04/21 01:27
# 3              80              90              5.14      US  02/04/21 01:27
# 4              82              92              4.66      US  02/04/21 01:23
# ..            ...             ...               ...     ...             ...
# 565            76              38              5.85      PA  02/04/21 01:29
# 566            83               0              1.54      ZA  02/04/21 01:29
# 567            84              56              0.89      DE  02/04/21 01:29
# 568            95              64              1.25      BR  02/04/21 01:29
# 569            88              20              2.06      ZA  02/04/21 01:25
#
# [570 rows x 10 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
date= clean_city_data.Date.tolist()[0][0:8]
ax1 = clean_city_data.plot.scatter(x="Latitude", y="Max Temperature (Celsius)")
ax1.set_title(f"City Latitude vs Max Temperature ({date})")
ax1.grid(True)
plt.savefig(f"output_data/City_Latitude_vs_Max_Temperature_Scatter_Plot.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
ax2 = clean_city_data.plot.scatter(x="Latitude", y="Humidity (%)")
ax2.set_title(f"City Latitude vs Humidity ({date})")
ax2.grid(True)
plt.savefig(f"output_data/City_Latitude_vs_Humidity_Scatter_Plot.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
ax3 = clean_city_data.plot.scatter(x="Latitude", y="Cloudiness (%)")
ax3.set_title(f"City Latitude vs Cloudiness ({date})")
ax3.grid(True)
plt.savefig(f"output_data/City_Latitude_vs_Cloudiness_Scatter_Plot.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
ax4 = clean_city_data.plot.scatter(x="Latitude", y="Wind Speed (mph)")
ax4.set_title(f"City Latitude vs Wind Speed ({date})")
ax4.grid(True)
plt.savefig(f"output_data/City_Latitude_vs_Wind_Speed_Scatter_Plot.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
north_df = clean_city_data.loc[clean_city_data.Latitude>=0].reset_index()
n_lat = north_df.Latitude
north_df
# Out:
#      level_0  index              City  Latitude  Longitude  \
# 0          0      0   Blagoveshchenka   52.8333    79.8667
# 1          1      1         Northport   33.2290   -87.5772
# 2          2      2           Talnakh   69.4865    88.3972
# 3          3      3     Saint Anthony   45.0205   -93.2180
# 4          4      4            Albany   42.6001   -73.9662
# ..       ...    ...               ...       ...        ...
# 395      560    560  Muroto-misakicho   33.2833   134.1500
# 396      561    561         La Grande   45.3246  -118.0877
# 397      563    563             Uptar   59.7500   150.9167
# 398      565    565             Pocrí    8.2667   -80.5500
# 399      567    567     Bad Krozingen   47.9167     7.7000
#
#      Max Temperature (Celsius)  Humidity (%)  Cloudiness (%)  \
# 0                        -3.97            97             100
# 1                         1.00            80               1
# 2                       -28.07            86              98
# 3                         0.00            80              90
# 4                        -2.22            82              92
# ..                         ...           ...             ...
# 395                      13.00            41              20
# 396                       1.67            80              87
# 397                     -21.70            86              80
# 398                      25.29            76              38
# 399                       7.22            84              56
#
#      Wind Speed (mph) Country            Date
# 0                2.50      RU  02/04/21 01:27
# 1                2.06      US  02/04/21 01:27
# 2                1.88      RU  02/04/21 01:27
# 3                5.14      US  02/04/21 01:27
# 4                4.66      US  02/04/21 01:23
# ..                ...     ...             ...
# 395              9.77      JP  02/04/21 01:28
# 396              1.38      US  02/04/21 01:28
# 397              5.85      RU  02/04/21 01:29
# 398              5.85      PA  02/04/21 01:29
# 399              0.89      DE  02/04/21 01:29
#
# [400 rows x 11 columns]

# %%
south_df = clean_city_data.loc[clean_city_data.Latitude<0].reset_index()
s_lat=south_df.Latitude
south_df
# Out:
#      level_0  index                     City  Latitude  Longitude  \
# 0          6      6              Port Alfred  -33.5906    26.8910
# 1          8      8                   Hobart  -42.8794   147.3294
# 2          9      9                  Mataura  -46.1927   168.8643
# 3         10     10                    Bluff  -46.6000   168.3333
# 4         16     16                 Souillac  -20.5167    57.5167
# ..       ...    ...                      ...       ...        ...
# 165      562    562                  Waipawa  -41.4122   175.5153
# 166      564    564  Puerto Baquerizo Moreno   -0.9000   -89.6000
# 167      566    566                   Durban  -29.8579    31.0292
# 168      568    568                  Tanhaçu  -14.0214   -41.2481
# 169      569    569               Oudtshoorn  -33.5907    22.2014
#
#      Max Temperature (Celsius)  Humidity (%)  Cloudiness (%)  \
# 0                        22.78            84              61
# 1                        26.11            57              40
# 2                        15.26            48               0
# 3                        13.66            64               0
# 4                        29.00            70              40
# ..                         ...           ...             ...
# 165                      16.67            67               6
# 166                      24.46            86              22
# 167                      26.11            83               0
# 168                      20.36            95              64
# 169                      18.00            88              20
#
#      Wind Speed (mph) Country            Date
# 0                1.34      ZA  02/04/21 01:26
# 1                4.63      AU  02/04/21 01:25
# 2                3.65      NZ  02/04/21 01:27
# 3               10.44      NZ  02/04/21 01:27
# 4                5.14      MU  02/04/21 01:27
# ..                ...     ...             ...
# 165             10.80      NZ  02/04/21 01:29
# 166              4.63      EC  02/04/21 01:29
# 167              1.54      ZA  02/04/21 01:29
# 168              1.25      BR  02/04/21 01:29
# 169              2.06      ZA  02/04/21 01:25
#
# [170 rows x 11 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
n_max_temp=north_df["Max Temperature (Celsius)"]
(slope_nt, intercept_nt, rvalue_nt, pvalue_nt, stderr_nt) = linregress(n_lat, n_max_temp)
regress_values_nt = n_lat * slope_nt + intercept_nt
line_eq_nt = "y = " + str(round(slope_nt,2)) + "x + " + str(round(intercept_nt,2))
axnt=plt.scatter(n_lat,n_max_temp)
plt.plot(n_lat,regress_values_nt,"r-")
plt.annotate(line_eq_nt,(0,-30),fontsize=15,color="red")
plt.ylabel("Max Temperature (Celsius)")
plt.xlabel('Latitude')
print(f"The r-squared is: {rvalue_nt**2}")
plt.show()
# Out:
# The r-squared is: 0.8240685906608275

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
s_max_temp=south_df["Max Temperature (Celsius)"]
(slope_st, intercept_st, rvalue_st, pvalue_st, stderr_st) = linregress(s_lat, s_max_temp)
regress_values_st = s_lat * slope_st + intercept_st
line_eq_st = "y = " + str(round(slope_st,2)) + "x + " + str(round(intercept_st,2))
axst=plt.scatter(s_lat,s_max_temp)
plt.plot(s_lat,regress_values_st,"r-")
plt.annotate(line_eq_st,(-50,31.5),fontsize=15,color="red")
plt.ylabel("Max Temperature (Celsius)")
plt.xlabel('Latitude')
print(f"The r-squared is: {rvalue_st**2}")
plt.show()
# Out:
# The r-squared is: 0.2322964611319392

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
n_humidity=north_df["Humidity (%)"]
(slope_nh, intercept_nh, rvalue_nh, pvalue_nh, stderr_nh) = linregress(n_lat, n_humidity)
regress_values_nh = n_lat * slope_nh + intercept_nh
line_eq_nh = "y = " + str(round(slope_nh,2)) + "x + " + str(round(intercept_nh,2))
axnt=plt.scatter(n_lat,n_humidity)
plt.plot(n_lat,regress_values_nh,"r-")
plt.annotate(line_eq_nh,(42,30),fontsize=15,color="red")
plt.ylabel("Humidity (%)")
plt.xlabel('Latitude')
print(f"The r-squared is: {rvalue_nh**2}")
plt.show()
# Out:
# The r-squared is: 0.18555945420486553

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
s_humidity=south_df["Humidity (%)"]
(slope_sh, intercept_sh, rvalue_sh, pvalue_sh, stderr_sh) = linregress(s_lat, s_humidity)
regress_values_sh = s_lat * slope_sh + intercept_sh
line_eq_sh = "y = " + str(round(slope_sh,2)) + "x + " + str(round(intercept_sh,2))
axnt=plt.scatter(s_lat,s_humidity)
plt.plot(s_lat,regress_values_sh,"r-")
plt.annotate(line_eq_sh,(-30,40),fontsize=15,color="red")
plt.ylabel("Humidity (%)")
plt.xlabel('Latitude')
print(f"The r-squared is: {rvalue_sh**2}")
plt.show()
# Out:
# The r-squared is: 0.06249905123373838

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
n_cloud=north_df["Cloudiness (%)"]
(slope_nc, intercept_nc, rvalue_nc, pvalue_nc, stderr_nc) = linregress(n_lat, n_cloud)
regress_values_nc = n_lat * slope_nc + intercept_nc
line_eq_nc = "y = " + str(round(slope_nc,2)) + "x + " + str(round(intercept_nc,2))
axnt=plt.scatter(n_lat,n_cloud)
plt.plot(n_lat,regress_values_nc,"r-")
plt.annotate(line_eq_nc,(20,30),fontsize=15,color="red")
plt.ylabel("Cloudiness (%)")
plt.xlabel('Latitude')
print(f"The r-squared is: {rvalue_nc**2}")
plt.show()
# Out:
# The r-squared is: 0.06967044116194289

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
s_cloud=south_df["Cloudiness (%)"]
(slope_sc, intercept_sc, rvalue_sc, pvalue_sc, stderr_sc) = linregress(s_lat, s_cloud)
regress_values_sc = s_lat * slope_sc + intercept_sc
line_eq_sc = "y = " + str(round(slope_sc,2)) + "x + " + str(round(intercept_sc,2))
axnt=plt.scatter(s_lat,s_cloud)
plt.plot(s_lat,regress_values_sc,"r-")
plt.annotate(line_eq_sc,(-45,65),fontsize=15,color="red")
plt.ylabel("Cloudiness (%)")
plt.xlabel('Latitude')
print(f"The r-squared is: {rvalue_sc**2}")
plt.show()
# Out:
# The r-squared is: 0.07742894735243613

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
n_ws=north_df['Wind Speed (mph)']
(slope_ns, intercept_ns, rvalue_ns, pvalue_ns, stderr_ns) = linregress(n_lat, n_ws)
regress_values_ns = n_lat * slope_ns + intercept_ns
line_eq_ns = "y = " + str(round(slope_ns,2)) + "x + " + str(round(intercept_ns,2))
axnt=plt.scatter(n_lat,n_ws)
plt.plot(n_lat,regress_values_ns,"r-")
plt.annotate(line_eq_ns,(5,13),fontsize=15,color="red")
plt.ylabel("Wind Speed (mph)")
plt.xlabel('Latitude')
print(f"The r-squared is: {rvalue_ns**2}")
plt.show()
# Out:
# The r-squared is: 6.673743982275573e-05

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
s_ws=south_df['Wind Speed (mph)']
(slope_ss, intercept_ss, rvalue_ss, pvalue_ss, stderr_ss) = linregress(s_lat, s_ws)
regress_values_ss = s_lat * slope_ss + intercept_ss
line_eq_ss = "y = " + str(round(slope_ss,2)) + "x + " + str(round(intercept_ss,2))
axnt=plt.scatter(s_lat,s_ws)
plt.plot(s_lat,regress_values_ss,"r-")
plt.annotate(line_eq_ss,(5,13),fontsize=15,color="red")
plt.ylabel("Wind Speed (mph)")
plt.xlabel('Latitude')
print(f"The r-squared is: {rvalue_ss**2}")
plt.show()
# Out:
# The r-squared is: 0.03789401468110118
